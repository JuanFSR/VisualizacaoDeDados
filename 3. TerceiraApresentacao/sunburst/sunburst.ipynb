# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../../data/pre_processado_data.csv', sep=',')

# %%
import plotly.express as px

fig = px.sunburst(df, path=['Área', 'Nome Fantasia'])
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
fig.write_html("sunburst.html")
