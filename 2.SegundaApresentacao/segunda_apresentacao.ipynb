# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../data/pre_processado_data.csv')
df.tail()
# Out:
#         Unnamed: 0 Região  UF          Cidade Sexo        Faixa Etária  \
# 124000      125475     SE  RJ  Rio de Janeiro    F     mais de 70 anos
# 124001      125476     SE  SP         Limeira    F         até 20 anos
# 124002      125477     SE  SP          Osasco    M  entre 21 a 30 anos
# 124003      125478     NE  PI        Teresina    F  entre 51 a 60 anos
# 124004      125479     SE  SP       São Paulo    M  entre 31 a 40 anos
#
#        Data Finalização  Tempo Resposta     Nome Fantasia  \
# 124000       2021-11-10            10.0          Correios
# 124001       2021-11-29             8.0       Decolar.com
# 124002       2021-11-27             6.0  PayPal do Brasil
# 124003       2021-11-27             9.0           Oi Fixo
# 124004       2021-11-11            10.0              Uber
#
#                                       Segmento de Mercado  ... Resolvida  \
# 124000           Empresas de Serviços Postais e Logística  ...         0
# ...

# %%
# Para plotar o cartograma utilizarei as bibliotecas abaixo
import geopandas
import geoplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\juanf\Documents\UTFPR\Visualizacao-De-Dados\2.SegundaApresentacao\segunda_apresentacao.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/juanf/Documents/UTFPR/Visualizacao-De-Dados/2.SegundaApresentacao/segunda_apresentacao.ipynb#ch0000002?line=0'>1</a> # Para plotar o cartograma utilizarei as bibliotecas abaixo
# ----> <a href='vscode-notebook-cell:/c%3A/Users/juanf/Documents/UTFPR/Visualizacao-De-Dados/2.SegundaApresentacao/segunda_apresentacao.ipynb#ch0000002?line=1'>2</a> import geopandas
#       <a href='vscode-notebook-cell:/c%3A/Users/juanf/Documents/UTFPR/Visualizacao-De-Dados/2.SegundaApresentacao/segunda_apresentacao.ipynb#ch0000002?line=2'>3</a> import geoplot
#
# ModuleNotFoundError: No module named 'geopandas'
