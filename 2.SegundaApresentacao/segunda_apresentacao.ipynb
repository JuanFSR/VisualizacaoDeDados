# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from PIL import Image    # to import the image

# %matplotlib inline

# %%
df = pd.read_csv('../data/pre_processado_data.csv', sep=',')
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Região', 'UF', 'Cidade', 'Sexo', 'Faixa Etária',
#        'Data Finalização', 'Tempo Resposta', 'Nome Fantasia',
#        'Segmento de Mercado', 'Área', 'Assunto', 'Grupo Problema', 'Problema',
#        'Como Comprou Contratou', 'Procurou Empresa', 'Respondida', 'Situação',
#        'Avaliação Reclamação', 'Nota do Consumidor', 'Finalizada avaliada',
#        'Finalizada não avaliada', 'Resolvida', 'Não Avaliada', 'Não Resolvida',
#        'até 20 anos', 'entre 21 a 30 anos', 'entre 31 a 40 anos',
#        'entre 41 a 50 anos', 'entre 51 a 60 anos', 'entre 61 a 70 anos',
#        'mais de 70 anos'],
#       dtype='object')

# %%
text = df['Assunto'].tolist()
words = " ".join(text)
caractere = "/"

for x in range(len(caractere)):
    words = words.replace(caractere[x], "")

# Verificando Assuntos
with open("Output.txt", "w") as text_file:
    text_file.write(words)

# %%
# Carregando imagem do brasil
wave_mask = np.array(Image.open( "../img/brazil.jpg"))

# Criando objeto nuvem de palavras
wordcloud =  WordCloud(stopwords=STOPWORDS,
                mask=wave_mask, background_color="black",
               max_words=2000, max_font_size=256,
               random_state=42, width=wave_mask.shape[1],
                height=wave_mask.shape[0])

wordcloud.generate(words)

# mostra nuvem de palavra no formato da imagem
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
wordcloud.to_file('wordcloud_brasil'+'.png')
